# %%
import warnings # 경고 메시지를 출력하지 않게 하기 위해 improt
warnings.filterwarnings("ignore") # 경고 메시지를 출력하지 않게 한다.
import numpy as np # 수치 계산, 배열 처리를 위해 import 한다.
import pandas as pd # 데이터 분석을 위한 전처리를 위해 import 한다.
import matplotlib as mpl # matplotlib에서 음수 데이터의 '-' 부호가 깨지는 것을 방지하기 위해 import한다.
mpl.rcParams['axes.unicode_minus'] = False # matplotlib에서 음수 데이터의 '-' 부호가 깨지는 것을 방지한다.
import matplotlib.pyplot as plt # 시각화를 하기 위해 import한다.
plt.rcParams["font.family"] = "Pretendard" # matplotlib에서 사용할 글꼴을 지정한다.
plt.rcParams["font.size"] = 10 # matplotlib에서 사용할 글꼴 크기를 지정한다.
import seaborn as sns # 시각화를 하기 위해 import한다. matplotlib 기반으로 만든 시각화 도구
from plotnine import * # R의 ggplot2 패키지를 사용하는 것처럼 만드는 시각화 도구를 import한다.
import missingno as msno # 누락값의 분포를 그래프 형태로 표현한다.
import folium

# %%
korea_food_data = pd.read_csv('./data/korea_food_data.CSV', encoding='cp949')
korea_food_data
# Out:
#                  시설명     카테고리1    카테고리2 카테고리3  시도 명칭   시군구 명칭 법정읍면동명칭 리 명칭  \
# 0            0731양꼬치  음식점/유흥시설   동아시아음식    인도    경기도  안산시 단원구     원곡동  NaN
# 1     08001BARCELONA  음식점/유흥시설  동남아시아음식    기타   충청남도      공주시      중동  NaN
# 2           10.5INCH  음식점/유흥시설     유럽음식  이탈리아    경기도  수원시 팔달구     남창동  NaN
# 3           1000란무까타  음식점/유흥시설  동남아시아음식    기타    경기도      평택시     평택동  NaN
# 4          100하노이쌀국수  음식점/유흥시설  동남아시아음식   베트남  서울특별시       중구     순화동  NaN
# ...              ...       ...      ...   ...    ...      ...     ...  ...
# 9497      YJN필리핀레스토랑  음식점/유흥시설  동남아시아음식   필리핀    경기도      평택시     평택동  NaN
# 9498         Yudakka  음식점/유흥시설   동아시아음식    일본  서울특별시      강남구     논현동  NaN
# 9499       YUMMYTHAI  음식점/유흥시설  동남아시아음식    태국  서울특별시      강북구     미아동  NaN
# 9500          ZAMZAM  음식점/유흥시설  동남아시아음식    기타    경기도      화성시     향남읍   평리
# 9501      ZAYTOON자이툰  음식점/유흥시설  동남아시아음식    기타    경기도      안성시     동본동  NaN
#
#               번지    도로명 이름  ...      주말 운영시간  무료주차 가능여부  발렛주차 가능여부  \
# 0       764-9 번지       관산길  ...         정보없음    무료주차 가능    발렛주차 불가
# 1     147-279 번지     제민천3길  ...    토 17시-24시    무료주차 가능    발렛주차 불가
# 2       113-5 번지       행궁로  ...         정보없음    무료주차 불가    발렛주차 불가
# 3       291-9 번지      중앙2로  ...         정보없음    무료주차 가능    발렛주차 불가
# 4         217 번지    서소문로9길  ...  토-일 10시-20시    무료주차 불가    발렛주차 불가
# ...          ...       ...  ...          ...        ...        ...
# 9497    71-17 번지       평택로  ...         정보없음    무료주차 불가    발렛주차 불가
# 9498    249-3 번지       언주로  ...         정보없음    무료주차 불가    발렛주차 불가
# 9499    75-89 번지   오패산로31길  ...         정보없음    무료주차 불가    발렛주차 불가
# 9500    30-23 번지    3.1만세로  ...         정보없음    무료주차 불가    발렛주차 불가
# 9501       61 번지  중앙로400번길  ...         정보없음    무료주차 불가    발렛주차 불가
#
#        유아의자 대여여부   휠체어 보유여부 애완동물 동반입장 가능여부 채식메뉴 보유여부     할랄음식 여부   글루텐프리 음식여부  \
# 0     유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 1     유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 2     유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 3     유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 4     유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# ...          ...        ...            ...       ...         ...          ...
# 9497  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 9498  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 있음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 9499  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 9500  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 9501  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
#
#            최종작성일
# 0     2022-11-30
# 1     2022-11-30
# 2     2022-11-30
# 3     2022-11-30
# 4     2022-11-30
# ...          ...
# 9497  2022-10-10
# 9498  2022-10-10
# 9499  2022-10-10
# 9500  2022-10-10
# 9501  2022-10-10
#
# [9502 rows x 28 columns]

# %%
korea_food_data[korea_food_data['채식메뉴 보유여부'] == '채식 메뉴 있음'].head()
# Out:
#                    시설명     카테고리1   카테고리2     카테고리3  시도 명칭 시군구 명칭 법정읍면동명칭 리 명칭  \
# 14   1914 Lounge & Bar  음식점/유흥시설    유럽음식  이탈리아 프랑스  서울특별시    강남구     역삼동  NaN
# 267               그라치에  음식점/유흥시설    유럽음식      이탈리아  부산광역시    영도구     청학동  NaN
# 365             까예데고미스  음식점/유흥시설    유럽음식       스페인  서울특별시    종로구     누하동  NaN
# 438             나무이자카야  음식점/유흥시설  동아시아음식        일본  서울특별시    강남구     역삼동  NaN
# 472             남산와이너리  음식점/유흥시설    유럽음식   포르투갈 유럽  서울특별시    용산구    이태원동  NaN
#
#              번지   도로명 이름  ...              주말 운영시간  무료주차 가능여부  발렛주차 가능여부  \
# 14       676 번지     테헤란로  ...  토 10시-01시,일 10시-24시    무료주차 불가    발렛주차 불가
# 267  148-160 번지     청학동로  ...    토-일 11시30분-21시30분    무료주차 불가    발렛주차 불가
# 365     36-1 번지   자하문로9길  ...       토-일 16시-21시50분    무료주차 불가    발렛주차 불가
# 438   696-43 번지      선릉로  ...       토-일 11시30분-05시    무료주차 불가    발렛주차 불가
# 472    282-7 번지  회나무로10길  ...  토 13시-23시,일 13시-22시    무료주차 가능    발렛주차 불가
#
#       유아의자 대여여부   휠체어 보유여부 애완동물 동반입장 가능여부 채식메뉴 보유여부     할랄음식 여부   글루텐프리 음식여부  \
# 14   유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 있음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 267  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 있음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 365  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 있음  할랄음식 메뉴 있음  글루텐프리 메뉴 없음
# 438  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 있음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 472  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장불가  채식 메뉴 있음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
#
#           최종작성일
# 14   2022-11-30
# 267  2022-11-30
# 365  2022-11-30
# 438  2022-11-30
# 472  2022-11-30
#
# [5 rows x 28 columns]

# %%
korea_food_data[korea_food_data['애완동물 동반입장 가능여부'] == '반려동물 동반 입장가능']
# Out:
#                 시설명     카테고리1    카테고리2   카테고리3    시도 명칭 시군구 명칭 법정읍면동명칭 리 명칭  \
# 129          거루캥테이블  음식점/유흥시설  오세아니아음식  호주 아시아    부산광역시   해운대구     송정동  NaN
# 133             게리가  음식점/유흥시설  동남아시아음식      기타  제주특별자치도   서귀포시     남원읍  신례리
# 163           고메303  음식점/유흥시설     유럽음식    이탈리아     경상남도    양산시     물금읍  가촌리
# 199            골드홀릭  음식점/유흥시설   동아시아음식      일본    인천광역시     중구   북성동1가  NaN
# 201            골든타이  음식점/유흥시설  동남아시아음식      태국    서울특별시    송파구     방이동  NaN
# ...             ...       ...      ...     ...      ...    ...     ...  ...
# 8287           하노이포  음식점/유흥시설  동남아시아음식     베트남    대구광역시     북구     대현동  NaN
# 8288          하노이포포  음식점/유흥시설  동남아시아음식     베트남    부산광역시    금정구     장전동  NaN
# 8289         하늘레스토랑  음식점/유흥시설     유럽음식    이탈리아    서울특별시    종로구     평창동  NaN
# 9161         KAMCHA  음식점/유흥시설   동아시아음식      홍콩    서울특별시    강남구     신사동  NaN
# 9427  THAO ANH QUAN  음식점/유흥시설  동남아시아음식     베트남      경기도    포천시     소흘읍  송우리
#
#              번지    도로명 이름  ...              주말 운영시간  무료주차 가능여부  발렛주차 가능여부  \
# 129    127-6 번지  송정중앙로5번길  ...       토-일 09시30분-21시    무료주차 가능    발렛주차 불가
# 133     71-3 번지      공천포로  ...          토-일 10시-18시    무료주차 가능    발렛주차 불가
# 163    705-3 번지       가촌로  ...    토-일 11시30분-21시30분    무료주차 가능    발렛주차 불가
# 199    98-12 번지     월미문화로  ...          토-일 11시-24시    무료주차 가능    발렛주차 불가
# 201    171-4 번지     위례성대로  ...          토-일 11시-22시    무료주차 가능    발렛주차 불가
# ...         ...       ...  ...                  ...        ...        ...
# 8287  112-42 번지     경대로5길  ...                 정보없음    무료주차 가능    발렛주차 불가
# 8288   117-1 번지  금강로369번길  ...           10시-20시30분    무료주차 가능    발렛주차 불가
# 8289   산6-18 번지      북악산로  ...              11시-21시    무료주차 불가    발렛주차 불가
# 9161   516-5 번지  강남대로156길  ...  토 11시-20시,일 11시-18시    무료주차 불가    발렛주차 불가
# 9427   106-6 번지      솔모루로  ...          토-일 11시-22시    무료주차 불가    발렛주차 불가
#
#        유아의자 대여여부   휠체어 보유여부 애완동물 동반입장 가능여부 채식메뉴 보유여부     할랄음식 여부   글루텐프리 음식여부  \
# 129   유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장가능  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 133   유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장가능  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 163   유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장가능  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 199   유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장가능  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 201   유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장가능  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# ...          ...        ...            ...       ...         ...          ...
# 8287  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장가능  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 8288  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장가능  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 8289  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장가능  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 9161  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장가능  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
# 9427  유아의자 대여 불가  휠체어 대여 불가   반려동물 동반 입장가능  채식 메뉴 없음  할랄음식 메뉴 없음  글루텐프리 메뉴 없음
#
#            최종작성일
# 129   2022-11-30
# 133   2022-11-30
# 163   2022-11-30
# 199   2022-11-30
# 201   2022-11-30
# ...          ...
# 8287  2022-11-30
# 8288  2022-11-30
# 8289  2022-11-30
# 9161  2022-11-30
# 9427  2022-11-30
#
# [480 rows x 28 columns]
